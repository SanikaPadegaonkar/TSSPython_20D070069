# %%
#Importing Required Libraries
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns

#Declaring the Hyperparameters

N = 50
T = 7
R = 0.8
M = 5
F = 0.0005   # 0.5% Brokerage fee

def GetData(NameOfFile):  
    df=pd.read_csv(NameOfFile,usecols=["datadate","tic","adjcp","open"])
    return df  # pd.DataFrame Object

def PartitionData(Data):
    DateToIndex = {}
    Partitioned_Data=[]
    for k in range (0,Data.shape[0]-30,30):
        Partitioned_Data.append(Data.iloc[k,k+30])
        DateToIndex[k/30]=Data.datadate[k]
    return Partitioned_Data , DateToIndex # List containing of the Data Partitioned according to Date, and the Dictionary mapping Dates to their index in the list
    
def GetMomentumBasedPriority(PartitionedDataFrameList, DateToIndex ,today):
  # PartitionedDataFrameList : Pandas DataFrame, The Output of your last function
  # DateToIndex : Dictionary mapping dates to their index in the PartitionedDataFrameList
  # today :  Today's date (string) In Format: YYYYMMDD


  #NdaysAgo is a datatime.date() object contining the required data, you need to convert it to a string and then check if its
  #actually there in the Data you have or will you have to get going using some other nearest date

    NdaysAgo = datetime.date(int(today[0:4]),int(today[4:6]),int(today[6:])) + datetime.timedelta(days = -N)

  #START CODE HERE!
    NdaysAgo_str=NdaysAgo.strftime("%Y%m%d")
    i=1
    if NdaysAgo_str not in DateToIndex.values():
        while True:
            if ((datetime.date(int(today[0:4]),int(today[4:6]),int(today[6:])) + datetime.timedelta(days = -N-i)).strftime("%Y%m%d") in DateToIndex.values() || (datetime.date(int(today[0:4]),int(today[4:6]),int(today[6:])) + datetime.timedelta(days = -N+i))).strftime("%Y%m%d"):
                if((datetime.date(int(today[0:4]),int(today[4:6]),int(today[6:])) + datetime.timedelta(days = -N-i)).strftime("%Y%m%d") in DateToIndex.values())
                    NdaysAgo=datetime.date(int(today[0:4]),int(today[4:6]),int(today[6:])) + datetime.timedelta(days = -N-i) in DateToIndex.values()
                    N=N+i
                if((datetime.date(int(today[0:4]),int(today[4:6]),int(today[6:])) + datetime.timedelta(days = -N+i))).strftime("%Y%m%d") in DateToIndex.values())
                    NdaysAgo=datetime.date(int(today[0:4]),int(today[4:6]),int(today[6:])) + datetime.timedelta(days = -N+i) in DateToIndex.values()
                    N=N-i
                break
            i++
            NdaysAgo_str=NdaysAgo.strftime("%Y%m%d")
    PartitionedDataFrameArray=np.array(ParttionedDataFrameList)
    MomentumList=[]
    index_today=list(DateToIndex.keys())[list(DateToIndex.values()).index(today)]
    index_NdaysAgo=list(DateToIndex.keys())[list(DateToIndex.values()).index(NdaysAgo_str)]
    for j in range (30):
        PriceToday[]
        PriceToday.append(PartiotionedDataFrameArray[index_today][j][2])
        PriceNdaysAgo[]
        PriceNdaysAgo.append(PartiotionedDataFrameArray[index_NdaysAgo][j][2])
    
    Momentum=np.array(PriceToday)-np.array(PriceNdaysAgo)
    
    for m in range(N)
        index=list(DateToIndex.keys())[list(DateToIndex.values()).index(index_NdaysAgo+m)]
        for j in range (30):
            Price=[]
            Price.append(PartiotionedDataFrameArray[index][j][2])
        Sum=Sum+np.array(Price)
    Mean=Sum/N
    MomentumbyMean=Momentum/Mean
    MomentumbyMean=np.sort(MomentumbyMean)[::-1]
    
    return MomentumbyMean #Numpy Array containing the Momentum divided by mean(in the N-day period considered) of all the 30 tickers, in the required order.
